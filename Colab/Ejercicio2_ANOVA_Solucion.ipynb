# %% [markdown]
# <a href="https://colab.research.google.com/github/emiliagyr/EstadisticaExperimental/blob/main/Colab/Ejercicio2_ANOVA_Solucion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pingouin
# !pip install pyreadstat

# %%
import pandas as pd
import seaborn as sns
import pingouin as pg

# %% [markdown]
# #Enunciado
# Muchas personas hoy en día sufren de hipertensión arterial. Algunos doctores recomiendan a sus pacientes dietas bajas en sal; mientras un laboratorio químico ha creado un nuevo fármaco que se cree es más eficiente que dicha dieta. Para comprobar que el tratamiento con la pastilla funcionaba mejor que solo las dietas bajas en sal, se selección a un grupo de 100 personas a las cuales se las distribuyo en 4 grupos diferentes. El primer grupo recibió una pastilla placebo que no tenía ningún efecto en el organismo de la persona. El segundo grupo recibió solo la pastilla generada por el laboratorio farmacéutico. El tercer grupo recibió tanto la pastilla como la dieta baja en sal y el cuarto grupo, recibió solo la dieta baja en sal. Los investigadores no quisieron realizar ninguna hipótesis debido a que tuvieron un grupo que no solo estuvo en una dieta baja de sal, sino que tomó la pastilla para la presión arterial alta. Asuma que no hay normalidad de los datos.

# %%
#VD: Hipertensión artrial
#VI: Tratamientos
    #N1: Pastilla placeno
    #N2: Pastilla del laboratorio
    #N3: Pastilla y dieta
    #N4: Dieta

#Diseño: Intersujeto

# %% [markdown]
# #1. Leer los datos del documento .sav (SPSS) o .csv (Excel)

# %%
df = pd.read_spss("Presion_arterial.sav")
df
# Out:
#                grupo  Presión
# 0      Dieta sin sal   167.59
# 1   Dieta y pastilla   159.58
# 2           Pastilla   171.38
# 3   Dieta y pastilla   143.15
# 4           Pastilla   177.19
# ..               ...      ...
# 95          Pastilla   135.39
# 96  Dieta y pastilla   142.70
# 97           Placebo   144.81
# 98  Dieta y pastilla   164.17
# 99           Placebo   134.82
#
# [100 rows x 2 columns]

# %% [markdown]
# #2. Estadisticos descriptivos

# %%
df.describe()
# Out:
#           Presión
# count  100.000000
# mean   149.647700
# std     12.916029
# min    113.980000
# 25%    141.367500
# 50%    148.690000
# 75%    158.497500
# max    178.840000

# %% [markdown]
# #4. Prueba de Kruskal Wallis

# %%
pg.kruskal(dv="Presión", between="grupo", data=df)
# Out:
#         Source  ddof1         H     p-unc
# Kruskal  grupo      3  9.952198  0.018977

# %% [markdown]
# # 5. Prueba U de Mann Whitney (independientes)

# %% [markdown]
# Pastilla vs. Dieta sin sal

# %%
pg.mwu(df[df["grupo"] == "Pastilla"]["Presión"], df[df["grupo"] == "Dieta sin sal"]["Presión"])
# Out:
#      U-val alternative     p-val      RBC     CLES
# MWU  297.0   two-sided  0.642805  0.07764  0.46118

# %% [markdown]
# Pastilla vs. Dieta y pastilla

# %%
pg.mwu(df[df["grupo"] == "Pastilla"]["Presión"], df[df["grupo"] == "Dieta y pastilla"]["Presión"])
# Out:
#      U-val alternative     p-val       RBC      CLES
# MWU  175.5   two-sided  0.123779  0.273292  0.363354

# %% [markdown]
# Placebo vs. Pastilla

# %%
pg.mwu(df[df["grupo"] == "Placebo"]["Presión"], df[df["grupo"] == "Pastilla"]["Presión"])
# Out:
#      U-val alternative     p-val       RBC      CLES
# MWU  250.0   two-sided  0.175902  0.223602  0.388199

# %% [markdown]
# Placebo vs. Dieta sin sal

# %%
pg.mwu(df[df["grupo"] == "Placebo"]["Presión"], df[df["grupo"] == "Dieta sin sal"]["Presión"])
# Out:
#      U-val alternative     p-val       RBC      CLES
# MWU  266.5   two-sided  0.040522  0.320153  0.339923

# %% [markdown]
# Placebo vs. Dieta y pastilla

# %%
pg.mwu(df[df["grupo"] == "Placebo"]["Presión"], df[df["grupo"] == "Dieta y pastilla"]["Presión"])
# Out:
#      U-val alternative     p-val       RBC      CLES
# MWU  137.0   two-sided  0.001568  0.534014  0.232993

# %% [markdown]
# Dieta sin sal vs. Dieta y pastilla

# %%
pg.mwu(df[df["grupo"] == "Dieta sin sal"]["Presión"], df[df["grupo"] == "Dieta y pastilla"]["Presión"])
# Out:
#      U-val alternative     p-val       RBC      CLES
# MWU  246.0   two-sided  0.337234  0.163265  0.418367

# %% [markdown]
# #6. Comparación de medianas

# %% [markdown]
# Solo se encuentran diferencias significativas entre:
# - Placebo y Dieta y pastilla (p = 0.001)
# - Placebo y Dieta sin sal (p = 0.04)

# %%
df[df["grupo"] == "Placebo"]["Presión"].median()
# Out:
# 144.185

# %%
df[df["grupo"] == "Dieta y pastilla"]["Presión"].median()
# Out:
# 155.7

# %%
df[df["grupo"] == "Dieta sin sal"]["Presión"].median()
# Out:
# 152.915
