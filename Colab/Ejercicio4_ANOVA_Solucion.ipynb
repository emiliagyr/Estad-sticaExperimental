# %% [markdown]
# <a href="https://colab.research.google.com/github/emiliagyr/EstadisticaExperimental/blob/main/Colab/Ejercicio4_ANOVA_Solucion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pingouin
# !pip install pyreadstat

# %%
import pandas as pd
import seaborn as sns
import pingouin as pg

# %% [markdown]
# #Enunciado
# Durante las elecciones del 2021, una muestra conformada por 523 participantes, aproximadamente la mitad de ellos simpatizantes del partido “Perú Libre” y la mitad restante simpatizantes del partido “Fuerza Popular” fueron evaluados en tres momentos distintos sobre el nivel de satisfacción con su candidato(a).
#
#
# b. Por otro lado, como se tuvieron muestras similares en costa, sierra y selva se esperaron resultados específicos por región: a) se esperaba que en la selva la satisfacción hacia Fuerza Popular mejore en el tiempo y b) se esperaba que en la sierra la satisfacción hacia Perú Libre se fortalezca en el tiempo.
#
# Asuma una distribución no normal de todos los datos.

# %% [markdown]
# ##a. En general los investigadores esperaron que la satisfacción de los simpatizantes de Fuerza Popular no se modifique en el tiempo, de igual manera con los simpatizantes de Perú Libre.
# Asuma una distribución no normal de todos los datos.

# %%
#VD: Satisfacción de los simpatizantes de FP
#VI: Momentos de evaluación
    #N1: MED3
    #N2: MED5
    #N3: MED6

#Diseño: Intrasujeto

# %% [markdown]
# ##Hipotesis
# HT: N1 = N2 = N3 = N4
#
# HO: N1 = N2 = N3 = N4
#
# H1: Al menos 2 medidas son diferentes

# %% [markdown]
# #1. Leer los datos del documento .sav (SPSS) o .csv (Excel)

# %%
df = pd.read_spss("Voto_2021.sav")
df
# Out:
#                  PV REGION  MED3  MED5  MED6
# 0        Perú Libre  Costa   3.0   1.0   3.0
# 1        Perú Libre  Costa   4.0   2.0   4.0
# 2        Perú Libre  Costa   3.0   3.0   3.0
# 3        Perú Libre  Costa   4.0   1.0   3.0
# 4        Perú Libre  Costa   4.0   1.0   2.0
# ..              ...    ...   ...   ...   ...
# 518  Fuerza Popular  Selva   2.0   2.0   2.0
# 519  Fuerza Popular  Selva   3.0   2.0   2.0
# 520  Fuerza Popular  Selva   3.0   3.0   3.0
# 521  Fuerza Popular  Selva   3.0   3.0   3.0
# 522  Fuerza Popular  Selva   3.0   2.0   4.0
#
# [523 rows x 5 columns]

# %%
df['subject'] = df.index // 1
df
# Out:
#                  PV REGION  MED3  MED5  MED6  subject
# 0        Perú Libre  Costa   3.0   1.0   3.0        0
# 1        Perú Libre  Costa   4.0   2.0   4.0        1
# 2        Perú Libre  Costa   3.0   3.0   3.0        2
# 3        Perú Libre  Costa   4.0   1.0   3.0        3
# 4        Perú Libre  Costa   4.0   1.0   2.0        4
# ..              ...    ...   ...   ...   ...      ...
# 518  Fuerza Popular  Selva   2.0   2.0   2.0      518
# 519  Fuerza Popular  Selva   3.0   2.0   2.0      519
# 520  Fuerza Popular  Selva   3.0   3.0   3.0      520
# 521  Fuerza Popular  Selva   3.0   3.0   3.0      521
# 522  Fuerza Popular  Selva   3.0   2.0   4.0      522
#
# [523 rows x 6 columns]

# %%
melt_df = pd.melt(
    df, value_name="satisf", var_name="momentos", id_vars=["PV", "REGION", "subject"]
)
melt_df
# Out:
#                   PV REGION  subject momentos  satisf
# 0         Perú Libre  Costa        0     MED3     3.0
# 1         Perú Libre  Costa        1     MED3     4.0
# 2         Perú Libre  Costa        2     MED3     3.0
# 3         Perú Libre  Costa        3     MED3     4.0
# 4         Perú Libre  Costa        4     MED3     4.0
# ...              ...    ...      ...      ...     ...
# 1564  Fuerza Popular  Selva      518     MED6     2.0
# 1565  Fuerza Popular  Selva      519     MED6     2.0
# 1566  Fuerza Popular  Selva      520     MED6     3.0
# 1567  Fuerza Popular  Selva      521     MED6     3.0
# 1568  Fuerza Popular  Selva      522     MED6     4.0
#
# [1569 rows x 5 columns]

# %% [markdown]
# #2. Estadisticos descriptivos

# %%
df.describe()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-d9569b4d2c84> in <cell line: 1>()
# ----> 1 df.describe().append(df.median().rename('median'))
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#    5990
#    5991     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %% [markdown]
# # 3. Prueba de Friedman

# %%
filtered_df_FP = melt_df[melt_df['PV'] == 'Fuerza Popular']
pg.friedman(data=filtered_df_FP, dv='satisf', within='momentos', subject="subject")
# Out:
#             Source         W  ddof1           Q         p-unc
# Friedman  momentos  0.273483      2  144.399033  4.407055e-32

# %%
filtered_df_PL = melt_df[melt_df2['PV'] == 'Perú Libre']
pg.friedman(data=filtered_df_PL, dv='satisf', within='momentos', subject="subject")
# Out:
#             Source         W  ddof1           Q         p-unc
# Friedman  momentos  0.272056      2  139.292831  5.661689e-31

# %%
#Separamos los datos de los 3 grupos para FUERZA POPULAR
med3_data = filtered_df_FP[filtered_df_FP["momentos"] == "MED3"]["satisf"]
med6_data = filtered_df_FP[filtered_df_FP["momentos"] == "MED6"]["satisf"]
med5_data = filtered_df_FP[filtered_df_FP["momentos"] == "MED5"]["satisf"]

# Realizar el test de Wilcoxon
pg.wilcoxon(med3_data, med6_data)
# Out:
#            W-val alternative         p-val       RBC      CLES
# Wilcoxon  5663.0   two-sided  3.112117e-08 -0.442096  0.348793

# %%
# Realizar el test de Wilcoxon
pg.wilcoxon(med3_data, med5_data)
# Out:
#            W-val alternative         p-val      RBC      CLES
# Wilcoxon  2398.0   two-sided  1.105497e-16  0.69209  0.676868

# %%
# Realizar el test de Wilcoxon
pg.wilcoxon(med6_data, med5_data)
# Out:
#            W-val alternative         p-val       RBC      CLES
# Wilcoxon  2337.0   two-sided  5.970088e-24  0.791022  0.782175

# %% [markdown]
# ##Ya sabemos que sí hay diferencia entre los grupos, ahora necesitamos saber entre cuales. Como son no parametricos, usaremos medianas.

# %%
df.median(numeric_only=True)
# Out:
# MED3         3.0
# MED5         2.0
# MED6         3.0
# subject    261.0
# dtype: float64

# %%
med3_range = (med3_data.min(), med3_data.max())
med6_range = (med6_data.min(), med6_data.max())

# Print the ranges
print("Range for MED3:", med3_range)
print("Range for MED6:", med6_range)
# Out:
# Range for MED3: (1.0, 5.0)
# Range for MED6: (1.0, 5.0)
