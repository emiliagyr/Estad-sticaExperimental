# %% [markdown]
# <a href="https://colab.research.google.com/github/emiliagyr/EstadisticaExperimental/blob/main/Colab/2vias_sol1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pingouin
# !pip install pyreadstat

# %%
import pandas as pd
import seaborn as sns
import pingouin as pg
import matplotlib.pyplot as plt

# %% [markdown]
# #Enunciado
# La especialidad de Psicología se encuentra preocupada por las conductas de riesgo que los jóvenes estudiantes realizan después del evento anual denominado Psicodía. Según información disponible, estas conductas de riesgo se encontrarían relacionadas al tipo de alcohol ingerido durante el evento.
# De esta forma, se ha planteado realizar un experimento en el cual se ofrecen 5 tipos de bebidas:
# 1. Cerveza
# 2. Chilcano, mezcla de jugo de limón y pisco
# 3. Chicharron, es decir Chicha y Ron
# 4. Sangría, mezcla de jugo y vino
# 5. Cuba libre, mezcla de ron y coca cola.
# Para realizar el estudio se trabaja con alumnos de los dos primeros ciclos de la carrera: Primer ciclo y Segundo ciclo.
# Las conductas de riesgo fueron registradas por medio de la escala Heisenberg.
# Se desea saber si los puntajes en la escala difieren por el tipo de bebida ingerida y el ciclo al que pertenecen los alumnos. Además, se quiere saber si el consumo de chicharrón en alumnos del segundo ciclo genera más conductas de riesgo que el consumo de cerveza en alumnos del primer ciclo.

# %% [markdown]
# Variable independiente 1
#
# H0: u1 = U2 = U3 = U4 (las mediciones son iguales)
# H1: Al menos 2 son distintos
#
# Variable independiente 2
#
# H0: u1 = U2 = U3 = U4 (las mediciones son iguales)
# H1: Al menos 2 son distintos
#
# Interacción
#
# H0: No hay interacción
# H1: Si hay interacción

# %% [markdown]
# #1. Leer los datos del documento .sav (SPSS) o .csv (Excel)

# %%
df = pd.read_spss("Psicodia.sav")
df
# Out:
#     Caso     Bebidas          Ciclo  Riesgo
# 0    1.0     Cerveza  Segundo ciclo    29.0
# 1    2.0     Cerveza  Segundo ciclo    25.0
# 2    3.0     Cerveza  Segundo ciclo    37.0
# 3    4.0     Cerveza   Primer ciclo    46.0
# 4    5.0     Cerveza   Primer ciclo    35.0
# 5    6.0     Cerveza   Primer ciclo    28.0
# 6    7.0     Cerveza  Segundo ciclo    19.0
# 7    8.0     Cerveza  Segundo ciclo    24.0
# 8    9.0     Cerveza  Segundo ciclo    30.0
# 9   10.0     Cerveza   Primer ciclo    30.0
# 10  11.0     Cerveza   Primer ciclo    31.0
# 11  12.0     Cerveza   Primer ciclo    25.0
# 12  13.0    Chilcano  Segundo ciclo    39.0
# 13  14.0    Chilcano  Segundo ciclo    38.0
# 14  15.0    Chilcano  Segundo ciclo    44.0
# 15  16.0    Chilcano   Primer ciclo    50.0
# 16  17.0    Chilcano   Primer ciclo    42.0
# 17  18.0    Chilcano   Primer ciclo    39.0
# 18  19.0    Chilcano  Segundo ciclo    22.0
# 19  20.0    Chilcano  Segundo ciclo    27.0
# ...

# %% [markdown]
# ##3. Anova 2 vías

# %%
pg.anova(dv="Riesgo", between=["Bebidas", "Ciclo"], data=df)
# Out:
#             Source           SS  DF          MS         F     p-unc       np2
# 0          Bebidas   922.433333   4  230.608333  5.405305  0.001072  0.301883
# 1            Ciclo   370.016667   1  370.016667  8.672943  0.004891  0.147818
# 2  Bebidas * Ciclo     7.233333   4    1.808333  0.042386  0.996483  0.003379
# 3         Residual  2133.166667  50   42.663333       NaN       NaN       NaN

# %% [markdown]
# Se aceptan las 2 hipótesis intersujeto e intrasujeto
# Pero no la hipótesis de interacción

# %% [markdown]
# ##5. Graficar los datos

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.pointplot(data=df, x='Bebidas', y='Riesgo', hue='Ciclo',  markers=['o', 's', 'D', 'X'], linestyles=['-', '--', '-.', ':'])
plt.title('Interaction ')
plt.xlabel('Bebidas')
plt.ylabel('Riesgo')
plt.legend(title='Ciclo')
plt.show()

# %% [markdown]
# ##6. Post-Hoc

# %%
from statsmodels.stats.anova import anova_lm
from statsmodels.formula.api import ols
from statsmodels.stats.multicomp import pairwise_tukeyhsd

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd

# Perform post hoc Tukey HSD test for NSE
tukey_nse = pairwise_tukeyhsd(endog=df['Riesgo'], groups=df['Bebidas'], alpha=0.05)
print(tukey_nse)
tukey_nse.plot_simultaneous()
plt.title('Tukey HSD Test for NSE')
plt.xlabel('Mean Difference')
plt.grid(True)
plt.show()
# Out:
#      Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
#   group1     group2   meandiff p-adj   lower    upper  reject
# -------------------------------------------------------------
#    Cerveza Chicharron      8.0 0.0409   0.2211 15.7789   True
#    Cerveza   Chilcano   6.6667 0.1261  -1.1122 14.4455  False
#    Cerveza Cuba libre   3.4167 0.7289  -4.3622 11.1955  False
#    Cerveza    Sangria  -2.4167 0.9044 -10.1955  5.3622  False
# Chicharron   Chilcano  -1.3333 0.9886  -9.1122  6.4455  False
# Chicharron Cuba libre  -4.5833 0.4656 -12.3622  3.1955  False
# Chicharron    Sangria -10.4167 0.0035 -18.1955 -2.6378   True
#   Chilcano Cuba libre    -3.25 0.7636 -11.0289  4.5289  False
#   Chilcano    Sangria  -9.0833 0.0144 -16.8622 -1.3045   True
# Cuba libre    Sangria  -5.8333 0.2285 -13.6122  1.9455  False
# -------------------------------------------------------------
